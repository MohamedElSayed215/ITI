# %%
#(1) Please write a function named triangle, 
#which draws a triangle of 
#hashes, and takes one argument. The triangle should be as tall and 
#as wide as the value of the argument

def triangle(num):
    for i in range(1,num+1):
        print(i*'#')

triangle(6)
# Out:
# #
# ##
# ###
# ####
# #####
# ######

# %%
#(2)  Please write a function named greatest_number, 
# which takes three arguments. The function returns the greatest in value of the three
def max_num(num1,num2,num3):
    if num1 >= num2 and num1 >= num3 :
        return num1 
    elif num2 > num1 and num2 >num3 :
        return num2
    else :
        return num3
print(max_num(10,10,5))
# Out:
# 10

# %%
#(2) Another Way ! 
def max_num(num1,num2,num3):
    if(num1>num2):
        if(num1>num3):
            return num1 
    elif(num2>num1):
        if(num2>num3):
            return num2
        else:
            return num3
    

print(max_num(4,9,3))
# Out:
# 9

# %%
#(3) Write a function sum_series(n) that calculates the sum of the 
#series: 
#1 - 2 + 3 - 4 + 5 - ... up to n
def sum_series(num):
    sum=0
    for i in range(num+1):
        if (i%2==0):
            sum+=-1*i
        else:
            sum+=i

    return sum

print(sum_series(5))
# Out:
# 3

# %%
#(4) Write a Python function to calculate the factorial of a number 
# (a non-negative integer). The function accepts the number as an 
#argument.
def fact_num(num):
    if (num > 0):
        fact=1
        for i in range (1,num+1):
            fact*=i
        print(f'result = {fact}')
    else : 
        print('Invalid value ! ')         


fact_num(5)
# Out:
# result = 120

# %%
#(5)  Implement a function that checks if a given word is a palindrome 
#(reads the same forwards and backwards)

def IsPalindrome(word):
    word=word.lower()
    reversed_word = ""
    for char in word:
        reversed_word =  char + reversed_word 
        print(reversed_word)        
    if(word == reversed_word):
        print("Yes , it is Palindrome ! ")
    else :
        print("Yes , it isn't Palindrome ! ")   

IsPalindrome('Mohamed ElSayed')
IsPalindrome('Madam')
# Out:
# m
# om
# hom
# ahom
# mahom
# emahom
# demahom
#  demahom
# e demahom
# le demahom
# sle demahom
# asle demahom
# yasle demahom
# eyasle demahom
# deyasle demahom
# Yes , it isn't Palindrome !
# m
# am
# dam
# adam
# madam
# Yes , it is Palindrome !
